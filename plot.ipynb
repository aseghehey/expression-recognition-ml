# %%
import numpy as np
import FileReading as fr
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
originalData = fr.GetData()[1]
translatedData = fr.GetData(manipulation="Translated")[1]
rotatedXData = fr.GetData(manipulation="RotatedX")[1]
rotatedYData = fr.GetData(manipulation="RotatedY")[1]
rotatedZData = fr.GetData(manipulation="RotatedZ")[1]

# %%
o = originalData[0].reshape(83, 3)
t = translatedData[99].reshape(83, 3)
rx = rotatedXData[180].reshape(83, 3)
ry = rotatedYData[60399].reshape(83, 3)
rz = rotatedZData[-1].reshape(83, 3)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter3D(t[:, 0], t[:, 1], t[:, 2], alpha=1, color='red')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.view_init(90)
plt.show()
